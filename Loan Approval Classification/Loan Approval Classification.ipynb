# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:black;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h1 style='padding: 20px;
#               color:white;
#               text-align:center;'>
#         Import Needed Libraries
#     </h1>
#     </div>

# %%
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import iplot , plot
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from plotly.subplots import make_subplots
from sklearn.preprocessing import MinMaxScaler , LabelEncoder , StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectPercentile, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier , BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
import tensorflow as tf
import keras
from sklearn.metrics import  ConfusionMatrixDisplay, classification_report , accuracy_score , confusion_matrix
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:black;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h1 style='padding: 20px;
#               color:white;
#               text-align:center;'>
#         Reading Dataset And Get Info
#     </h1>
#     </div>

# %%
df = pd.read_csv('loan_data.csv')

# %%
# Show Sample of Data
df.sample(5)
# Out:
#        person_age person_gender person_education  person_income  \
# 43060        24.0        female        Associate        31173.0
# 18910        32.0          male        Associate        56042.0
# 9720         24.0          male      High School        77959.0
# 31310        43.0        female        Associate       104206.0
# 21243        28.0        female        Associate        36633.0
#
#        person_emp_exp person_home_ownership  loan_amnt      loan_intent  \
# 43060               0                  RENT     8500.0          MEDICAL
# 18910              11                  RENT     1800.0          MEDICAL
# 9720                5              MORTGAGE     6000.0          VENTURE
# 31310              21              MORTGAGE     6500.0  HOMEIMPROVEMENT
# 21243               5                  RENT     5200.0         PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 43060          12.81                 0.27                         2.0
# 18910          11.58                 0.03                         9.0
# 9720           10.75                 0.08                         3.0
# 31310           7.74                 0.06                        13.0
# 21243           5.42                 0.14                         7.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 43060           616                             No            1
# 18910           657                            Yes            0
# 9720            691                            Yes            0
# 31310           663                            Yes            0
# 21243           583                            Yes            0

# %%
# Show Shape of Data
print(f"Number of Row : {df.shape[0]}\nNumber of Columns : {df.shape[1]}")
# Out:
# Number of Row : 45000
# Number of Columns : 14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
#  12  previous_loan_defaults_on_file  45000 non-null  object
#  13  loan_status                     45000 non-null  int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 4.8+ MB

# %%
# Check for Data Leakage
pd.crosstab(df['previous_loan_defaults_on_file'], df['loan_status'], normalize='index')
# Out:
# loan_status                           0        1
# previous_loan_defaults_on_file
# No                              0.54837  0.45163
# Yes                             1.00000  0.00000

# %%
# Remove 'previous_loan_defaults_on_file' cause that lead to data leakage
df = df.drop(columns=['previous_loan_defaults_on_file'])

# %%
# Check NaN Value
df.isna().sum()
# Out:
# person_age                    0
# person_gender                 0
# person_education              0
# person_income                 0
# person_emp_exp                0
# person_home_ownership         0
# loan_amnt                     0
# loan_intent                   0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_cred_hist_length    0
# credit_score                  0
# loan_status                   0
# dtype: int64

# %%
# Describe Numiric Data
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# 25%         8.590000             0.070000                    3.000000
# 50%        11.010000             0.120000                    4.000000
# 75%        12.990000             0.190000                    8.000000
# max        20.000000             0.660000                   30.000000
#
#        credit_score   loan_status
# count  45000.000000  45000.000000
# mean     632.608756      0.222222
# std       50.435865      0.415744
# min      390.000000      0.000000
# 25%      601.000000      0.000000
# 50%      640.000000      0.000000
# 75%      670.000000      0.000000
# max      850.000000      1.000000

# %% [markdown]
# - Maximum person age 144 not reality
# - person_income (Annual income) and person_emp_exp (Years of employment experience) in my opinion contain outlier

# %%
pd.DataFrame({'Count':df.shape[0],
              'Null':df.isnull().sum(),
              'Null %':df.isnull().mean() * 100,
              'Cardinality':df.nunique()
})
# Out:
#                             Count  Null  Null %  Cardinality
# person_age                  45000     0     0.0           60
# person_gender               45000     0     0.0            2
# person_education            45000     0     0.0            5
# person_income               45000     0     0.0        33989
# person_emp_exp              45000     0     0.0           63
# person_home_ownership       45000     0     0.0            4
# loan_amnt                   45000     0     0.0         4483
# loan_intent                 45000     0     0.0            6
# loan_int_rate               45000     0     0.0         1302
# loan_percent_income         45000     0     0.0           64
# cb_person_cred_hist_length  45000     0     0.0           29
# credit_score                45000     0     0.0          340
# loan_status                 45000     0     0.0            2

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:black;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h1 style='padding: 20px;
#               color:white;
#               text-align:center;'>
#         Detection Outliers
#     </h1>
#     </div>

# %%
def detect_outliers_iqr(df, columns, threshold = 1.5):

    outlier_indices = {}

    for col in columns:
        Q1 = df[col].quantile(0.25)  # 25th percentile
        Q3 = df[col].quantile(0.75)  # 75th percentile
        IQR = Q3 - Q1  # Interquartile range
        lower_bound = Q1 - threshold * IQR
        upper_bound = Q3 + threshold * IQR

        # Finding outliers
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)].index.tolist()
        outlier_indices[col] = outliers
    
    return outlier_indices

numerical_columns = ['person_age','person_income','person_emp_exp','loan_amnt','loan_int_rate','loan_percent_income',
                     'cb_person_cred_hist_length','credit_score']
outliers_iqr = detect_outliers_iqr(df, numerical_columns)

for col, indices in outliers_iqr.items():
    print(f"{col}: {len(indices)} outliers detected")
# Out:
# person_age: 2188 outliers detected
# person_income: 2218 outliers detected
# person_emp_exp: 1724 outliers detected
# loan_amnt: 2348 outliers detected
# loan_int_rate: 124 outliers detected
# loan_percent_income: 744 outliers detected
# cb_person_cred_hist_length: 1366 outliers detected
# credit_score: 467 outliers detected

# %%
plt.figure(figsize=(15, 6))

for i, col in enumerate(numerical_columns, 1):
    plt.subplot(4, 2, i)  
    sns.boxplot(x = df[col], color = "skyblue")
    plt.title(f"Box Plot of {col}")

plt.tight_layout() 
plt.show()

# %%
def remove_outliers(df, columns, threshold = 1.5):
    df_clean = df.copy()
    for col in columns:
        Q1 = df_clean[col].quantile(0.25)  # First quartile (25%)
        Q3 = df_clean[col].quantile(0.75)  # Third quartile (75%)
        IQR = Q3 - Q1  # Interquartile range
        lower_bound = Q1 - threshold * IQR
        upper_bound = Q3 + threshold * IQR
        
        df_clean = df_clean[(df_clean[col] > lower_bound) & (df_clean[col] < upper_bound)]
    
    return df_clean

df_cleaned = remove_outliers(df, numerical_columns)

# %%
# The New of Shape Cleaned Data
print(f"Number of Row : {df_cleaned.shape[0]}\nNumber of Columns : {df_cleaned.shape[1]}")
# Out:
# Number of Row : 35630
# Number of Columns : 13

# %%
plt.figure(figsize=(15, 6))

for i, col in enumerate(numerical_columns, 1):
    plt.subplot(4, 2, i) 
    sns.boxplot(x = df_cleaned[col], color = "skyblue")
    plt.title(f"Box Plot of {col}")

plt.tight_layout()
plt.show()

# %%
df_cleaned.reset_index(inplace = True , drop = True)
df_cleaned.sample(5)
# Out:
#        person_age person_gender person_education  person_income  \
# 26616        31.0          male        Associate       145207.0
# 15441        22.0          male      High School        79956.0
# 26604        26.0          male      High School        49491.0
# 16536        29.0          male        Associate        38948.0
# 16333        27.0        female         Bachelor        29874.0
#
#        person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 26616               8              MORTGAGE     6000.0    PERSONAL
# 15441               4              MORTGAGE    10000.0     VENTURE
# 26604               3              MORTGAGE     6508.0     VENTURE
# 16536               8                  RENT     2100.0    PERSONAL
# 16333               4                  RENT     1450.0     MEDICAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 26616          10.53                 0.04                         8.0
# 15441          11.49                 0.13                         4.0
# 26604           9.53                 0.13                         5.0
# 16536          11.01                 0.05                         6.0
# 16333          11.01                 0.05                         9.0
#
#        credit_score  loan_status
# 26616           598            0
# 15441           572            0
# 26604           591            0
# 16536           596            0
# 16333           690            0

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35630 entries, 0 to 35629
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  35630 non-null  float64
#  1   person_gender               35630 non-null  object
#  2   person_education            35630 non-null  object
#  3   person_income               35630 non-null  float64
#  4   person_emp_exp              35630 non-null  int64
#  5   person_home_ownership       35630 non-null  object
#  6   loan_amnt                   35630 non-null  float64
#  7   loan_intent                 35630 non-null  object
#  8   loan_int_rate               35630 non-null  float64
#  9   loan_percent_income         35630 non-null  float64
#  10  cb_person_cred_hist_length  35630 non-null  float64
#  11  credit_score                35630 non-null  int64
#  12  loan_status                 35630 non-null  int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 3.5+ MB

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:black;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h1 style='padding: 20px;
#               color:white;
#               text-align:center;'>
#          EDA of Data and Get Insights
#     </h1>
#     </div>

# %% [markdown]
# ## Does Age Affect on Their Status of Loan ?

# %%
plt.figure(figsize=(15,6))

plt.subplot(2,1,1)

plt.title('Distribution of Age and Loan Status Approved or Not')
sns.kdeplot(df_cleaned[(df_cleaned['loan_status'] == 0)]['person_age'],color='red',fill=True,label='Loan Rejected')
sns.kdeplot(df_cleaned[(df_cleaned['loan_status'] == 1)]['person_age'],color='green',fill=True,label='Loan Approved')

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# - Most of the ages of those who are accepted for loans range between 20 and 25. After this age, obtaining loans becomes more difficult.

# %% [markdown]
# ## What is the gender of those whose loan application is accepted more ?

# %%
fig = px.pie(values = df_cleaned['person_gender'].value_counts(),
             names = ['male','female'],
             template = 'plotly_dark',
             title = 'The Percentage of Gender'
             ).update_traces(textinfo='label+percent')
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="a02bed31-9d3f-43b6-9f55-246f197b83e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a02bed31-9d3f-43b6-9f55-246f197b83e1")) {                    Plotly.newPlot(                        "a02bed31-9d3f-43b6-9f55-246f197b83e1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["male","female"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i2","bdata":"Okz0Pg=="},"type":"pie","textinfo":"label+percent"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"line":{"color":"#283442"}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colo ...

# %% [markdown]
# - Males are the most in demand for loans.

# %%
fig = px.histogram(
    df_cleaned, 
    x='person_gender', 
    color='loan_status', 
    barmode='group',  
    title='Loan Acceptance by Gender (1 = approved; 0 = rejected)',
    labels={'count': 'Count','loan_status':'Loan Status','person_gender':'Person Gender'},
    template='plotly_dark',
    text_auto=True,
    color_discrete_map = {0:'#c71818',1:'#05fa15'}
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="e22d903b-7bf2-4bc2-bfd0-d6b1b5d43215" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e22d903b-7bf2-4bc2-bfd0-d6b1b5d43215")) {                    Plotly.newPlot(                        "e22d903b-7bf2-4bc2-bfd0-d6b1b5d43215",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Loan Status=0\u003cbr\u003ePerson Gender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#c71818","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["female","female","male","male","male","female","female","female","female","male","female","male","female","female","female","female","male","female","female","female","male","female","female","female","male","male","female","male","male","female","female","female","female","female","female","male","male","female","female","male","male","male","male","male","male","female","male","male","female","male","male","male","male","female","female","female","female","male","male","male","male","male","male","male","male","male","male","male","male","male","female","male","female","male","female","male","male","male","male","male","male","male","female","male","female","male","female","male","male","female","female","female","female","male","female","female","female","male","female","female","female","male","female","female","male","female","male","female","male","male","male","female","male","male","male","female","male","female","male","female","female","female","female","female","male","female","female","female","male","female","female","male","female","female","female","male","male","female","male","male","male","female","male","male","female","male","male","female","male","female","male","female","female","male","female","male","female","male","female","male","female","female","male","male","male","male","male","male","female","male","male","female","female","male","male","female","female","male","male","female","male","female","female","male","female","male","female","male","female","male","male","male","male","female","female","male","male","female","female","male","female","male","male","female","female","female","male","male","male","male","female","male","male","male","female","male","male","male","female","male","female","female","female","female","male","female","female","male","female","male","female","female","male","female","male","male","male","female","female","female","female","female","female","male","female","male","male","male","male","female","female","female","male","female","female","male","female","male","male","female","female","male","male","female","male","female","female","female","female","female","male","male","male","female","male","male","male","female","male","female","male","female","male","male","female","male","male","female","male","male","female","female","female","male","female","male","male","male","male","female","female","male","male","male","female","female","female","male","female","male","male","female","female","female","female","female","male","male","male","male","male","female","female","female","male","male","male","male","male","male","female","male","female","male","male","male","male","male","female","female","male","male","male","female","male","male","male","female","male","male","male","male","male","female","female","female","female","female","male","male","male","male","male","female","male","female","female","male","female","male","female","male","male","female","female","male","male","male","female","male","female","male","male","male","female","female","male","male","female","female","male","female","female","male","ma ...

# %% [markdown]
# - Gender does not affect obtaining a loan.

# %% [markdown]
# ## Loan Approval by Education Level

# %%
fig = px.bar(df_cleaned['person_education'].value_counts(), 
    color=df_cleaned['person_education'].value_counts().index, 
    title='What most Education Level who needed Loan ?',
    labels={'person_education': 'Person Education','value':'Count','color':'Education Level'},
    template='plotly_dark',
    text_auto=True
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="cf14bd29-7cdb-4048-865b-300f55c270ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cf14bd29-7cdb-4048-865b-300f55c270ad")) {                    Plotly.newPlot(                        "cf14bd29-7cdb-4048-865b-300f55c270ad",                        [{"hovertemplate":"Education Level=Bachelor\u003cbr\u003ePerson Education=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bachelor","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bachelor","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bachelor"],"xaxis":"x","y":{"dtype":"i2","bdata":"UCs="},"yaxis":"y","type":"bar"},{"hovertemplate":"Education Level=Associate\u003cbr\u003ePerson Education=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Associate","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Associate","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Associate"],"xaxis":"x","y":{"dtype":"i2","bdata":"SSQ="},"yaxis":"y","type":"bar"},{"hovertemplate":"Education Level=High School\u003cbr\u003ePerson Education=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High School","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"High School","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["High School"],"xaxis":"x","y":{"dtype":"i2","bdata":"0CM="},"yaxis":"y","type":"bar"},{"hovertemplate":"Education Level=Master\u003cbr\u003ePerson Education=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Master","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Master","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Master"],"xaxis":"x","y":{"dtype":"i2","bdata":"aRY="},"yaxis":"y","type":"bar"},{"hovertemplate":"Education Level=Doctorate\u003cbr\u003ePerson Education=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Doctorate","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Doctorate","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Doctorate"],"xaxis":"x","y":{"dtype":"i2","bdata":"XAE="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd ...

# %% [markdown]
# - Most Education Level who needed Loan is Bachelor

# %%
fig = px.histogram(
    df_cleaned, 
    x='person_education', 
    color='loan_status', 
    barmode='group',  
    title='Loan Acceptance by Education Level (1 = approved; 0 = rejected)',
    labels={'count': 'Count','person_education': 'Person Education','loan_status':'Loan Status'},
    template='plotly_dark',
    text_auto=True,
    color_discrete_map = {0:'#c71818',1:'#05fa15'}
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="c773082d-427d-4a3d-baf2-34678be4577f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c773082d-427d-4a3d-baf2-34678be4577f")) {                    Plotly.newPlot(                        "c773082d-427d-4a3d-baf2-34678be4577f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Loan Status=0\u003cbr\u003ePerson Education=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#c71818","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["High School","Bachelor","High School","Associate","Associate","Bachelor","Bachelor","High School","High School","Master","Bachelor","High School","Associate","High School","Bachelor","High School","High School","Associate","Bachelor","High School","Bachelor","Bachelor","Bachelor","Master","Associate","Bachelor","Associate","High School","Bachelor","Bachelor","Bachelor","High School","Bachelor","High School","Associate","Associate","Master","Associate","Master","High School","Associate","Bachelor","Associate","Bachelor","Associate","High School","Bachelor","Associate","Associate","Associate","Associate","Bachelor","Bachelor","Associate","Bachelor","Associate","Master","Associate","Bachelor","High School","Bachelor","Associate","Bachelor","Associate","Master","Associate","Associate","Associate","Associate","High School","Associate","Master","High School","Bachelor","Master","High School","High School","Bachelor","Bachelor","Bachelor","High School","High School","High School","High School","Bachelor","High School","Master","High School","Bachelor","Associate","Bachelor","Bachelor","Associate","Master","Bachelor","Bachelor","Bachelor","Associate","Associate","High School","High School","Bachelor","Bachelor","Associate","Bachelor","Bachelor","Bachelor","High School","Master","Master","Master","Associate","High School","High School","Bachelor","High School","High School","Associate","Associate","High School","Bachelor","Bachelor","High School","Bachelor","Master","Bachelor","Bachelor","Bachelor","High School","High School","Associate","Associate","Associate","Associate","Bachelor","Master","Master","Bachelor","Master","High School","Bachelor","Bachelor","Associate","High School","Bachelor","Associate","High School","Bachelor","Bachelor","Bachelor","Associate","Bachelor","Bachelor","Associate","Bachelor","Master","Master","Associate","High School","Bachelor","Bachelor","High School","Bachelor","Associate","Master","Bachelor","Associate","High School","High School","Associate","Associate","Associate","Bachelor","High School","Bachelor","Associate","Associate","High School","Associate","Bachelor","Bachelor","High School","High School","Associate","Bachelor","High School","Master","Master","Bachelor","High School","High School","Associate","Associate","Bachelor","Bachelor","Bachelor","Associate","Bachelor","High School","Bachelor","Associate","Bachelor","High School","High School","Master","Bachelor","Bachelor","Bachelor","Associate","High School","Bachelor","Associate","Associate","Associate","Bachelor","Associate","Associate","High School","High School","Master","Bachelor","Bachelor","High School","Associate","Bachelor","Bachelor","Bachelor","Master","Master","High School","Master","Associate","High School","Associate","Bachelor","High School","Associate","High School","Associate","High School","High School","High School","Bachelor","Bachelor","Bachelor","Bachelor","Associate","Master","Bachelor","Bachelor","Master","High School","Master","Bachelor","Associate","High School","Associate","High School","Associate","Bachelor","High School","Master","Bachelor","High School","Mas ...

# %% [markdown]
# - Education Level not affect on Loan Approval

# %% [markdown]
# ## Annual income and Loan amount requested

# %%
plt.figure(figsize=(15,6))

plt.subplot(2,1,1)

plt.title('Annual income of the person whose loan application is approved')
sns.kdeplot(df_cleaned[(df_cleaned['loan_status'] == 0)]['person_income'],color='red',fill=True,label='Loan Rejected')
sns.kdeplot(df_cleaned[(df_cleaned['loan_status'] == 1)]['person_income'],color='green',fill=True,label='Loan Approved')

plt.legend()

plt.subplot(2,1,2)

plt.title('Loan amount requested')
sns.kdeplot(df_cleaned[(df_cleaned['loan_status'] == 0)]['loan_amnt'],color='red',fill=True,label='Loan Rejected')
sns.kdeplot(df_cleaned[(df_cleaned['loan_status'] == 1)]['loan_amnt'],color='green',fill=True,label='Loan Approved')

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# - Most annual income loan accepted less than 50000 (more than that rejected)
# - loan amount accepted around than 15000 and more (less than may rejected)

# %%
df_cleaned.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        21.0        female      High School        12282.0               0
# 1        21.0        female      High School        12951.0               0
# 2        21.0        female      High School        12739.0               0
# 3        24.0        female           Master        14283.0               1
# 4        24.0        female         Bachelor        13866.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                   OWN     1000.0   EDUCATION          11.14
# 1                   OWN     2500.0     VENTURE           7.14
# 2                   OWN     1600.0     VENTURE          14.74
# 3              MORTGAGE     1750.0   EDUCATION          10.99
# 4                   OWN     1500.0    PERSONAL           7.29
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  loan_status
# 0                 0.08                         2.0           504            0
# 1                 0.19                         2.0           532            1
# 2                 0.13                         3.0           640            1
# 3                 0.12                         2.0           679            1
# 4                 0.11                         3.0           600            0

# %% [markdown]
# ## Is Home ownership status affect ?

# %%
fig = px.histogram(
    df_cleaned, 
    x='person_home_ownership', 
    color='loan_status', 
    barmode='group',  
    title='Loan Acceptance by Home ownership status (1 = approved; 0 = rejected)',
    labels={'count': 'Count','person_home_ownership': 'Home ownership status','loan_status':'Loan Status'},
    template='plotly_dark',
    text_auto=True,
    color_discrete_map = {0:'#c71818',1:'#05fa15'}
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="a3e82165-5f11-4321-8548-779cf13b2d3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a3e82165-5f11-4321-8548-779cf13b2d3f")) {                    Plotly.newPlot(                        "a3e82165-5f11-4321-8548-779cf13b2d3f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Loan Status=0\u003cbr\u003eHome ownership status=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#c71818","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["OWN","OWN","OWN","OWN","MORTGAGE","OWN","OWN","MORTGAGE","MORTGAGE","OWN","MORTGAGE","OWN","MORTGAGE","OWN","MORTGAGE","OWN","MORTGAGE","MORTGAGE","MORTGAGE","OWN","OWN","MORTGAGE","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","OWN","RENT","RENT","OWN","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","OWN","OWN","MORTGAGE","MORTGAGE","OWN","MORTGAGE","OWN","OWN","MORTGAGE","OWN","MORTGAGE","MORTGAGE","MORTGAGE","MORTGAGE","OWN","MORTGAGE","OWN","MORTGAGE","MORTGAGE","OWN","OWN","OWN","OWN","OWN","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","MORTGAGE","RENT","RENT","OTHER","RENT","RENT","RENT","MORTGAGE","RENT","RENT","RENT","RENT","RENT","MORTGAGE","OWN","RENT","RENT","RENT","OWN","MORTGAGE","MORTGAGE","RENT","MORTGAGE","OWN","MORTGAGE","MORTGAGE","RENT","RENT","RENT","RENT","OWN","RENT","RENT","MORTGAGE","RENT","OWN","MORTGAGE","RENT","RENT","RENT","RENT","RENT","OWN","RENT","RENT","OWN","RENT","RENT","MORTGAGE","RENT","MORTGAGE","RENT","RENT","RENT","RENT","RENT","MORTGAGE","RENT","RENT","MORTGAGE","RENT","RENT","MORTGAGE","RENT","RENT","RENT","RENT","OWN","RENT","MORTGAGE","RENT","OWN","RENT","OWN","OWN","RENT","OWN","RENT","RENT","OWN","MORTGAGE","RENT","MORTGAGE","OWN","RENT","RENT","RENT","RENT","RENT","RENT","MORTGAGE","MORTGAGE","RENT","OWN","RENT","RENT","MORTGAGE","RENT","RENT","MORTGAGE","RENT","MORTGAGE","MORTGAGE","MORTGAGE","MORTGAGE","RENT","RENT","RENT","RENT","MORTGAGE","OTHER","RENT","RENT","RENT","RENT","RENT","OWN","OWN","RENT","RENT","RENT","MORTGAGE","RENT","RENT","RENT","RENT","OWN","RENT","RENT","RENT","OWN","RENT","RENT","OWN","MORTGAGE","MORTGAGE","RENT","MORTGAGE","MORTGAGE","MORTGAGE","OWN","MORTGAGE","MORTGAGE","OWN","OWN","OWN","OWN","OWN","OWN","RENT","RENT","RENT","RENT","MORTGAGE","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","OWN","RENT","MORTGAGE","RENT","RENT","OWN","RENT","RENT","RENT","RENT","RENT","RENT","RENT","MORTGAGE","MORTGAGE","RENT","MORTGAGE","RENT","MORTGAGE","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","OWN","OWN","RENT","RENT","OWN","OWN","RENT","MORTGAGE","MORTGAGE","MORTGAGE","RENT","RENT","RENT","RENT","MORTGAGE","MORTGAGE","OWN","MORTGAGE","OWN","OWN","RENT","RENT","RENT","RENT","RENT","MORTGAGE","MORTGAGE","RENT","RENT","RENT","RENT","RENT","OWN","OWN","OWN","OWN","OWN","RENT","OWN","RENT","RENT","OWN","RENT","RENT","RENT","RENT","RENT","RENT","RENT","MORTGAGE","RENT","RENT","RENT","RENT","RENT","RENT","RENT","MORTGAGE","OWN","MORTGAGE","RENT","RENT","RENT","RENT","RENT","RENT","RENT","RENT","OWN","RENT","RENT","RENT","OWN","MORTGAGE","OWN","RENT","MORTGAGE","RENT","MORTGAGE","MORTGAGE","OWN","OWN","MORTGAGE","OWN","MORTGAGE","MORTGAGE","MORTGAGE","OWN","MORTGAGE","OWN","OWN","MORTGAGE","OWN","MORTGAGE","OWN","RENT","RENT","RENT","RENT","MORTGAGE","RENT","OWN","RENT","RENT","RENT","MORTGAGE","MORTGAGE","MORTGAGE","MORTGAGE","RENT","RENT","RENT","MORTGAGE","RENT","OWN","RENT","RENT","RENT","RENT","OTHER","MORTGAGE","RENT","RENT","RENT","RENT","MORTGAGE","REN ...

# %% [markdown]
# - Most Approval are Home Ownership Rent

# %% [markdown]
# ## Total Insights
# - Most of the ages of those who are accepted for loans range between 20 and 25. After this age, obtaining loans becomes more difficult.
# - Males are the most in demand for loans.
# - Gender does not affect obtaining a loan.
# - Most Education Level who needed Loan is Bachelor
# - Education Level not affect on Loan Approval
# - Most annual income loan accepted less than 50000 (more than that rejected)
# - loan amount accepted around than 15000 and more (less than may rejected)
# - Most Approval are Home Ownership Rent

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:black;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h1 style='padding: 20px;
#               color:white;
#               text-align:center;'>
#          Data Preprocessing
#     </h1>
#     </div>

# %% [markdown]
# ## Handling Object DataType

# %% [markdown]
# ### Encode Object DataType

# %%
column_to_encode = df_cleaned.select_dtypes(object).columns.tolist()
le = LabelEncoder()
for column in column_to_encode:
    df_cleaned[column] = le.fit_transform(df_cleaned[column])

# %%
# Show Data After some of Encode
df_cleaned.head()
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 0        21.0              0                 3        12282.0               0
# 1        21.0              0                 3        12951.0               0
# 2        21.0              0                 3        12739.0               0
# 3        24.0              0                 4        14283.0               1
# 4        24.0              0                 1        13866.0               0
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0                      2     1000.0            1          11.14
# 1                      2     2500.0            5           7.14
# 2                      2     1600.0            5          14.74
# 3                      0     1750.0            1          10.99
# 4                      2     1500.0            4           7.29
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  loan_status
# 0                 0.08                         2.0           504            0
# 1                 0.19                         2.0           532            1
# 2                 0.13                         3.0           640            1
# 3                 0.12                         2.0           679            1
# 4                 0.11                         3.0           600            0

# %%
# Final Info after Encode
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35630 entries, 0 to 35629
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  35630 non-null  float64
#  1   person_gender               35630 non-null  int32
#  2   person_education            35630 non-null  int32
#  3   person_income               35630 non-null  float64
#  4   person_emp_exp              35630 non-null  int64
#  5   person_home_ownership       35630 non-null  int32
#  6   loan_amnt                   35630 non-null  float64
#  7   loan_intent                 35630 non-null  int32
#  8   loan_int_rate               35630 non-null  float64
#  9   loan_percent_income         35630 non-null  float64
#  10  cb_person_cred_hist_length  35630 non-null  float64
#  11  credit_score                35630 non-null  int64
#  12  loan_status                 35630 non-null  int64
# dtypes: float64(6), int32(4), int64(3)
# memory usage: 3.0 MB

# %% [markdown]
# ## Assign feature and target variables

# %%
fig = px.imshow(df_cleaned.corr(), 
                text_auto=True, 
                color_continuous_scale = "tempo",  
                template='plotly_dark',
                title="Correlation Heatmap")
fig.update_layout(
    width=1000, 
    height=800  
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="2805f544-2561-4fa3-b794-daee88915a8a" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2805f544-2561-4fa3-b794-daee88915a8a")) {                    Plotly.newPlot(                        "2805f544-2561-4fa3-b794-daee88915a8a",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["person_age","person_gender","person_education","person_income","person_emp_exp","person_home_ownership","loan_amnt","loan_intent","loan_int_rate","loan_percent_income","cb_person_cred_hist_length","credit_score","loan_status"],"y":["person_age","person_gender","person_education","person_income","person_emp_exp","person_home_ownership","loan_amnt","loan_intent","loan_int_rate","loan_percent_income","cb_person_cred_hist_length","credit_score","loan_status"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D\u002fSudTzUHN\u002fv0NHPPpkXZ6\u002f+Vjnq3ipuj8qa7ripUvsP6lES59AXaO\u002fXRHfTA76pj+H6G12It6dPzi7PCqAH2I\u002fqPIIyOK6oL9kbWPfOsjoPz6ME\u002fl6qr0\u002foDiVCiC4mr\u002fSudTzUHN\u002fvwAAAAAAAPA\u002f0IcW\u002fl5FW7+foOAP9E+IPzRgD2U36Ii\u002fGu7ThfULC7+tKQ9sBN15P\u002f7tTeDpp3q\u002f+InYC0NoUT8GpiKRhDZKv1YDBSpJNoa\u002fWWw4r0cTc79Zohv2jbxkP0NHPPpkXZ6\u002f0IcW\u002fl5FW78AAAAAAADwPw\u002fxad0w3Wc\u002feVXFV\u002f4Rm79QEx5T40hgv4QOUhHiGk6\u002f3sg0eLqoaT8T7g8qpSJzPwMigKQiG3C\u002f2QsYzy0Xmb8kM7lYgqmSP3MFqj4JzFI\u002f+Vjnq3ipuj+foOAP9E+IPw\u002fxad0w3Wc\u002fAAAAAAAA8D8JPVBz1Ua1P6k8vzTooNa\u002fZZ0+vGoG2D9QUFjFpdJrv+\u002fhJDLamrC\u002f8oRb+QQP178aOcQELiqxP9FdLKunmY0\u002fQBIZeK2a0L8qa7ripUvsPzRgD2U36Ii\u002feVXFV\u002f4Rm78JPVBz1Ua1PwAAAAAAAPA\u002f\u002fSzdF2I6ob88\u002fn6o2I2jPwE8qo8hLZw\u002fJG+R8V67gD9RsmoFFPuXv4nZf9SjKOY\u002fES3noyp9wD88weIjwtuWv6lES59AXaO\u002fGu7ThfULC79QEx5T40hgv6k8vzTooNa\u002f\u002fSzdF2I6ob8AAAAAAADwPzesLz6Yob+\u002fs1BKR+h3JL8AsHKN35fDP3Fr0Y7locI\u002frQ4pSP8Xmr\u002f5NfDRSxtzvyogimGXD8o\u002fXRHfTA76pj+tKQ9sBN15P4QOUhHiGk6\u002fZZ0+vGoG2D88\u002fn6o2I2jPzesLz6Yob+\u002fAAAAAAAA8D+gaS5sEWQsvwZx0OzyNrU\u002fOJ0q6MKR5D\u002faXEHuXU+eP0CaW6OSM0I\u002flXDgLM+Spj+H6G12It6dP\u002f7tTeDpp3q\u002f3sg0eLqoaT9QUFjFpdJrvwE8qo8hLZw\u002fs1BKR+h3JL+gaS5sEWQsvwAAAAAAAPA\u002fkSJ8sqH5cL\u002fCRNGPiI5iP6cc\u002fOpicpk\u002fsRyz87dfjD9454mLthiyvzi7PCqAH2I\u002f+InYC0NoUT8T7g8qpSJzP+\u002fhJDLamrC\u002fJG+R8V67gD8AsHKN35fDPwZx0OzyNrU\u002fkSJ8sqH5cL8AAAAAAADwP4\u002ftJBbWlbw\u002fIOTER0+3iD\u002fN78eR\u002fKZ2Pw85fl2A8NQ\u002fqPIIyOK6oL8GpiKRhDZKvwMigKQiG3C\u002f8oRb+QQP179RsmoFFPuXv3Fr0Y7locI\u002fOJ0q6MKR5D\u002fCRNGPiI5iP4\u002ftJBbWlbw\u002fAAAAAAAA8D+TOIhCDcOUv9sdljt194q\u002f\u002f6YNBXoR1D9kbWPfOsjoP1YDBSpJNoa\u002f2QsYzy0Xmb8aOcQELiqxP4nZf9SjKOY\u002frQ4pSP8Xmr\u002faXEHuXU+eP6cc\u002fOpicpk\u002fIOTER0+3iD+TOIhCDcOUvwAAAAAAAPA\u002fu6t7jdtOuT87iGu0aGuTvz6ME\u002fl6qr0\u002fWWw4r0cTc78kM7lYgqmSP9FdLKunmY0\u002fES3noyp9wD\u002f5NfDRSxtzv0CaW6OSM0I\u002fsRyz87dfjD\u002fN78eR\u002fKZ2P9sdljt194q\u002fu6t7jdtOuT8AAAAAAADwP8IkgLcxAIy\u002foDiVCiC4mr9Zohv2jbxkP3MFqj4JzFI\u002fQBIZeK2a0L88weIjwtuWvyogimGXD8o\u002flXDgLM+Spj9454mLthiyvw85fl2A8NQ\u002f\u002f6YNBXoR1D87iGu0aGuTv8IkgLcxAIy\u002fAAAAAAAA8D8=","shape":"13, 13"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":" ...

# %%
X = df_cleaned.drop('loan_status' , axis = 1)
y = df_cleaned['loan_status']

def FeatureSelectionByPercentile(X,y,Percentile) : 
    FeatureSelection = SelectPercentile(score_func = f_classif, percentile=Percentile)
    X_Selected = FeatureSelection.fit_transform(X, y)
    NewData = pd.DataFrame(X_Selected,columns =[i for i,j in zip(X.columns,FeatureSelection.get_support()) if j ] )
    NewData['loan_status'] = y
    return NewData
    
NewData = FeatureSelectionByPercentile(X,y,80)      
NewData.head()
# Out:
#    person_age  person_income  person_emp_exp  person_home_ownership  \
# 0        21.0        12282.0             0.0                    2.0
# 1        21.0        12951.0             0.0                    2.0
# 2        21.0        12739.0             0.0                    2.0
# 3        24.0        14283.0             1.0                    0.0
# 4        24.0        13866.0             0.0                    2.0
#
#    loan_amnt  loan_intent  loan_int_rate  loan_percent_income  \
# 0     1000.0          1.0          11.14                 0.08
# 1     2500.0          5.0           7.14                 0.19
# 2     1600.0          5.0          14.74                 0.13
# 3     1750.0          1.0          10.99                 0.12
# 4     1500.0          4.0           7.29                 0.11
#
#    cb_person_cred_hist_length  loan_status
# 0                         2.0            0
# 1                         2.0            1
# 2                         3.0            1
# 3                         2.0            1
# 4                         3.0            0

# %%
fig = px.imshow(NewData.corr(), 
                text_auto=True, 
                color_continuous_scale = "tempo",  
                template='plotly_dark',
                title="Correlation Heatmap")
fig.update_layout(
    width=1000, 
    height=800  
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="1f957b30-391e-48e9-bf08-35cb44f5d7d1" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1f957b30-391e-48e9-bf08-35cb44f5d7d1")) {                    Plotly.newPlot(                        "1f957b30-391e-48e9-bf08-35cb44f5d7d1",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["person_age","person_income","person_emp_exp","person_home_ownership","loan_amnt","loan_intent","loan_int_rate","loan_percent_income","cb_person_cred_hist_length","loan_status"],"y":["person_age","person_income","person_emp_exp","person_home_ownership","loan_amnt","loan_intent","loan_int_rate","loan_percent_income","cb_person_cred_hist_length","loan_status"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D\u002f5WOereKm6PypruuKlS+w\u002fqURLn0Bdo79dEd9MDvqmP4fobXYi3p0\u002fOLs8KoAfYj+o8gjI4rqgv2RtY986yOg\u002foDiVCiC4mr\u002f5WOereKm6PwAAAAAAAPA\u002fCT1Qc9VGtT+pPL806KDWv2WdPrxqBtg\u002fUFBYxaXSa7\u002fv4SQy2pqwv\u002fKEW\u002fkED9e\u002fGjnEBC4qsT9AEhl4rZrQvypruuKlS+w\u002fCT1Qc9VGtT8AAAAAAADwP\u002f0s3RdiOqG\u002fPP5+qNiNoz8BPKqPIS2cPyRvkfFeu4A\u002fUbJqBRT7l7+J2X\u002fUoyjmPzzB4iPC25a\u002fqURLn0Bdo7+pPL806KDWv\u002f0s3RdiOqG\u002fAAAAAAAA8D83rC8+mKG\u002fv7NQSkfodyS\u002fALByjd+Xwz9xa9GO5aHCP60OKUj\u002fF5q\u002fKiCKYZcPyj9dEd9MDvqmP2WdPrxqBtg\u002fPP5+qNiNoz83rC8+mKG\u002fvwAAAAAAAPA\u002foGkubBFkLL8GcdDs8ja1PzidKujCkeQ\u002f2lxB7l1Pnj+VcOAsz5KmP4fobXYi3p0\u002fUFBYxaXSa78BPKqPIS2cP7NQSkfodyS\u002foGkubBFkLL8AAAAAAADwP5EifLKh+XC\u002fwkTRj4iOYj+nHPzqYnKZP3jniYu2GLK\u002fOLs8KoAfYj\u002fv4SQy2pqwvyRvkfFeu4A\u002fALByjd+Xwz8GcdDs8ja1P5EifLKh+XC\u002fAAAAAAAA8D+P7SQW1pW8PyDkxEdPt4g\u002fDzl+XYDw1D+o8gjI4rqgv\u002fKEW\u002fkED9e\u002fUbJqBRT7l79xa9GO5aHCPzidKujCkeQ\u002fwkTRj4iOYj+P7SQW1pW8PwAAAAAAAPA\u002fkziIQg3DlL\u002f\u002fpg0FehHUP2RtY986yOg\u002fGjnEBC4qsT+J2X\u002fUoyjmP60OKUj\u002fF5q\u002f2lxB7l1Pnj+nHPzqYnKZPyDkxEdPt4g\u002fkziIQg3DlL8AAAAAAADwPzuIa7Roa5O\u002foDiVCiC4mr9AEhl4rZrQvzzB4iPC25a\u002fKiCKYZcPyj+VcOAsz5KmP3jniYu2GLK\u002fDzl+XYDw1D\u002f\u002fpg0FehHUPzuIa7Roa5O\u002fAAAAAAAA8D8=","shape":"10, 10"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777777777 ...

# %%
X = NewData.drop(['loan_status'] , axis = 1)
y = NewData['loan_status']

# %%
# check for imbalanced data
counts = y.value_counts()
plt.bar(counts.index , counts.values)
plt.title('Destribuation of Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# ## Splitting Data

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.25 , random_state = 44 , shuffle = True)

# %%
print(f'Shape of X_Train {X_train.shape}')
print(f'Shape of X_Test {X_test.shape}')
print(f'Shape of Y_Train {y_train.shape}')
print(f'Shape of Y_Test {y_test.shape}')
# Out:
# Shape of X_Train (26722, 9)
# Shape of X_Test (8908, 9)
# Shape of Y_Train (26722,)
# Shape of Y_Test (8908,)

# %% [markdown]
# ### Handle Imbalanced Data

# %%
from imblearn.over_sampling import SMOTE
resampler = SMOTE()
X_train_resample,y_train_resample = resampler.fit_resample(X_train, y_train)

# %%
counts = y_train_resample.value_counts()
plt.bar(counts.index , counts.values)
plt.title('Destribuation of Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Counts')
plt.show()

# %%
# Show New Correlation
combined = pd.DataFrame(X_train_resample, columns=X_train.columns)
combined['loan_status'] = y_train_resample
fig = px.imshow(combined.corr(), 
                text_auto=True, 
                color_continuous_scale = "tempo",  
                template='plotly_dark',
                title="Correlation Heatmap")
fig.update_layout(
    width=1000, 
    height=800  
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="167d8924-ac92-44bc-b074-4e0d5734a8ad" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("167d8924-ac92-44bc-b074-4e0d5734a8ad")) {                    Plotly.newPlot(                        "167d8924-ac92-44bc-b074-4e0d5734a8ad",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["person_age","person_income","person_emp_exp","person_home_ownership","loan_amnt","loan_intent","loan_int_rate","loan_percent_income","cb_person_cred_hist_length","loan_status"],"y":["person_age","person_income","person_emp_exp","person_home_ownership","loan_amnt","loan_intent","loan_int_rate","loan_percent_income","cb_person_cred_hist_length","loan_status"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D8gTtgZvYi8P+mqw1VaWuw\u002f8IcQOLCPp78LsJk7l3CnP9rt2Fp5Q5I\u002fqDptjIkNaD9HbQNPrIGkv7ar8txMy+g\u002fL6DVi+wboL8gTtgZvYi8PwAAAAAAAPA\u002fEsNWjujytj+dl+7qC23Zv2aoJcI1e9g\u002fQ0kksD4dkb82XTHuxB2uv7SDrZ4\u002f4te\u002fuOQjlcHrsT8y1nzHRVXVv+mqw1VaWuw\u002fEsNWjujytj8AAAAAAADwP6d01j6LdqS\u002fro\u002fL1C2XpT9jg3Q2YAGSP1sk9MAP1ok\u002fhUBOLvrYm7+a9tBlzk3mP7AIbNP5gJi\u002f8IcQOLCPp7+dl+7qC23Zv6d01j6LdqS\u002fAAAAAAAA8D+Q7OOUdk21v5WRNyQosnU\u002feXqR4CmTwz9iqO\u002ff+X3NP6x4PjOt852\u002fJ72j5qaK0T8LsJk7l3CnP2aoJcI1e9g\u002fro\u002fL1C2XpT+Q7OOUdk21vwAAAAAAAPA\u002fRCOaiOXngb8wR4cEE060P\u002fXs64NE+uM\u002fdDoANoEnlj+Orvu45p+tP9rt2Fp5Q5I\u002fQ0kksD4dkb9jg3Q2YAGSP5WRNyQosnU\u002fRCOaiOXngb8AAAAAAADwP1RCaqbA756\u002fR3\u002fwb7RphD8Nz2bI4xuSP10ADFq8qLe\u002fqDptjIkNaD82XTHuxB2uv1sk9MAP1ok\u002feXqR4CmTwz8wR4cEE060P1RCaqbA756\u002fAAAAAAAA8D9FF+CMTBSzP+0Ya7aq45E\u002fTpITBFiw2T9HbQNPrIGkv7SDrZ4\u002f4te\u002fhUBOLvrYm79iqO\u002ff+X3NP\u002fXs64NE+uM\u002fR3\u002fwb7RphD9FF+CMTBSzPwAAAAAAAPA\u002fiq5NfMaaoL9imD1Jb8HWP7ar8txMy+g\u002fuOQjlcHrsT+a9tBlzk3mP6x4PjOt852\u002fdDoANoEnlj8Nz2bI4xuSP+0Ya7aq45E\u002fiq5NfMaaoL8AAAAAAADwP85EFpyf7Ze\u002fL6DVi+wboL8y1nzHRVXVv7AIbNP5gJi\u002fJ72j5qaK0T+Orvu45p+tP10ADFq8qLe\u002fTpITBFiw2T9imD1Jb8HWP85EFpyf7Ze\u002fAAAAAAAA8D8=","shape":"10, 10"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0," ...

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:black;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h1 style='padding: 20px;
#               color:white;
#               text-align:center;'>
#          Modeling
#     </h1>
#     </div>

# %% [markdown]
# ## Use Different Models Algorithm

# %%
def train(model,model_name,X_train,y_train,X_test,y_test):
    model.fit(X_train,y_train)
    model_train_score = model.score(X_train,y_train)
    model_test_score = model.score(X_test,y_test)
    print(f"{model_name} model score on Training data: {model_train_score * 100}%\n{model_name} model score on Testing data: {model_test_score * 100}%")

def class_report(model,X_test,y_test):
    y_pred = model.predict(X_test)
    print(classification_report(y_test, y_pred))

def plot_Conf_Matrix(model,X_test,y_test):
    y_pred = model.predict(X_test)
    CM = confusion_matrix(y_test, y_pred)
    sns.heatmap(CM, center=True, cmap='Blues_r', annot=True, fmt='g') 
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix")
    plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression()
train(lr, "Logistic Regression",X_train_resample,y_train_resample,X_test,y_test)
# Out:
# Logistic Regression model score on Training data: 74.74168701859854%
# Logistic Regression model score on Testing data: 72.38437359676695%

# %%
plot_Conf_Matrix(lr,X_test,y_test)

# %%
class_report(lr,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.72      0.81      7135
#            1       0.40      0.75      0.52      1773
#
#     accuracy                           0.72      8908
#    macro avg       0.66      0.73      0.66      8908
# weighted avg       0.82      0.72      0.75      8908

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(n_estimators = 40 , max_depth = 17)
train(rf, "Random Forest",X_train_resample,y_train_resample,X_test,y_test)
# Out:
# Random Forest model score on Training data: 97.45679128311103%
# Random Forest model score on Testing data: 90.25594970812753%

# %%
plot_Conf_Matrix(rf,X_test,y_test)

# %%
class_report(rf,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      7135
#            1       0.80      0.68      0.73      1773
#
#     accuracy                           0.90      8908
#    macro avg       0.86      0.82      0.84      8908
# weighted avg       0.90      0.90      0.90      8908

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier()
train(knn, "KNN",X_train_resample,y_train_resample,X_test,y_test)
# Out:
# KNN model score on Training data: 87.93678376855158%
# KNN model score on Testing data: 76.77368657386619%

# %%
plot_Conf_Matrix(knn,X_test,y_test)

# %%
class_report(knn,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.84      7135
#            1       0.45      0.68      0.54      1773
#
#     accuracy                           0.77      8908
#    macro avg       0.68      0.74      0.69      8908
# weighted avg       0.82      0.77      0.78      8908

# %% [markdown]
# ## Bagging

# %%
bagg_model = BaggingClassifier(n_estimators=35)
train(bagg_model, "Bagging",X_train_resample,y_train_resample,X_test,y_test)
# Out:
# Bagging model score on Training data: 99.94129250422694%
# Bagging model score on Testing data: 89.86304445442299%

# %%
plot_Conf_Matrix(bagg_model,X_test,y_test)

# %%
class_report(bagg_model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      7135
#            1       0.79      0.67      0.72      1773
#
#     accuracy                           0.90      8908
#    macro avg       0.86      0.81      0.83      8908
# weighted avg       0.89      0.90      0.90      8908

# %% [markdown]
# ## Gradient Boosting

# %%
gb_model = GradientBoostingClassifier(n_estimators=200)
train(gb_model, "Boosting",X_train_resample,y_train_resample,X_test,y_test)
# Out:
# Boosting model score on Training data: 93.30030058237836%
# Boosting model score on Testing data: 90.13246519982039%

# %%
plot_Conf_Matrix(gb_model,X_test,y_test)

# %%
class_report(gb_model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      7135
#            1       0.83      0.63      0.72      1773
#
#     accuracy                           0.90      8908
#    macro avg       0.87      0.80      0.83      8908
# weighted avg       0.90      0.90      0.90      8908

# %% [markdown]
# ## Decision Tree

# %%
dt_model = DecisionTreeClassifier(max_depth=15)
train(dt_model, "Decision Tree",X_train_resample,y_train_resample,X_test,y_test)
# Out:
# Decision Tree model score on Training data: 94.54724779259816%
# Decision Tree model score on Testing data: 87.53929052537045%

# %%
plot_Conf_Matrix(dt_model,X_test,y_test)

# %%
class_report(dt_model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      7135
#            1       0.70      0.65      0.67      1773
#
#     accuracy                           0.88      8908
#    macro avg       0.81      0.79      0.80      8908
# weighted avg       0.87      0.88      0.87      8908

# %% [markdown]
# ## Xgboost

# %%
xgboost = model = XGBClassifier(objective = "binary:logistic" , subsample = 0.7 , min_child_weight = 3,
                                max_depth = 25 , learning_rate = 0.1 , gamma = 0 , colsample_bytree = 0.5,)
train(xgboost, "Xgboost",X_train_resample,y_train_resample,X_test,y_test)
# Out:
# Xgboost model score on Training data: 98.32566222055232%
# Xgboost model score on Testing data: 91.62550516389763%

# %%
plot_Conf_Matrix(xgboost,X_test,y_test)

# %%
class_report(xgboost,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      7135
#            1       0.88      0.67      0.76      1773
#
#     accuracy                           0.92      8908
#    macro avg       0.90      0.82      0.85      8908
# weighted avg       0.91      0.92      0.91      8908

# %% [markdown]
# - Best Model is XGBoostClassifier with 92%

# %% [markdown]
# ## Save XGBoost Model

# %%
joblib.dump(xgboost,'xgboost.pkl')
joblib.dump(X_test,'x_test.pkl')
joblib.dump(y_test,'y_test.pkl')
# Out:
# ['y_test.pkl']
